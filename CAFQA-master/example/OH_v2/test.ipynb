# %%
# %run oh.py
# Out:
#  /home/ace/anaconda3/envs/QCfDD/lib/python3.9/site-packages/qiskit/providers/fake_provider/fake_backend.py:568: RuntimeWarning:Aer not found using BasicAer and no noise
# ---------------------------------------------------------------------------
# BasicAerError                             Traceback (most recent call last)
# File ~/github/QC_for_Drug_Discovery/CAFQA-master/example/OH_v2/oh.py:74
#      70         res_file.write(f"VQE params:\n{np.array(vqe_params)}\n\n")
#      73 if __name__ == "__main__":
# ---> 74     main()
#
# File ~/github/QC_for_Drug_Discovery/CAFQA-master/example/OH_v2/oh.py:54, in main()
#      52 loss_file = "vqe_loss.txt"
#      53 params_file = "vqe_params.txt"
# ---> 54 vqe_energy, vqe_params = run_vqe(
#      55     n_qubits=n_qubits,
#      56     coeffs=coeffs,
#      57     paulis=paulis,
#      58     param_guess=np.array(cafqa_params)*np.pi/2, #注意,cafqa_params是由CAFQA部分函数计算所得的在Clifford空间中最佳的参数,本段程序是想要在此基础上求得在vqe空间中的最佳参数,并优化cafqa部分所算得的energy的结果
# ...
